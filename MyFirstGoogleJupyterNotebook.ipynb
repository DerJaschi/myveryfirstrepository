# %% [markdown]
# <a href="https://colab.research.google.com/github/DerJaschi/myveryfirstrepository/blob/main/MyFirstGoogleJupyterNotebook.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello World!") #test
print('Sevinc')
# Out:
# Hello World!
# Sevinc

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import numpy as np
import pandas as pd

# %%
alpha = np.array([1,2,3])
bravo = np.array([2,2,2])

# %%
alpha
# Out:
# array([1, 2, 3])

# %%
dfa = pd.DataFrame(alpha)

# %%
dfb= pd.DataFrame(bravo)

# %%
alpha+bravo
# Out:
# array([3, 4, 5])

# %%
dfa.to_csv('alpha.csv', index=False)

# %%
dfb.to_csv('bravo.csv', index=False)

# %%
from google.colab import data_table

# %%
from vega_datasets import data

# %%
cars = data.cars()
cars
# Out:
#                           Name  Miles_per_Gallon  Cylinders  Displacement  \
# 0    chevrolet chevelle malibu              18.0          8         307.0
# 1            buick skylark 320              15.0          8         350.0
# 2           plymouth satellite              18.0          8         318.0
# 3                amc rebel sst              16.0          8         304.0
# 4                  ford torino              17.0          8         302.0
# ..                         ...               ...        ...           ...
# 401            ford mustang gl              27.0          4         140.0
# 402                  vw pickup              44.0          4          97.0
# 403              dodge rampage              32.0          4         135.0
# 404                ford ranger              28.0          4         120.0
# 405                 chevy s-10              31.0          4         119.0
#
#      Horsepower  Weight_in_lbs  Acceleration       Year  Origin
# ...
